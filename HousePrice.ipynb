# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --upgrade pip
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --upgrade pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("housing.csv",sep=",")

# %%
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %% [markdown]
# in total_bedrooms we have some values missing we only have 20433 non null

# %%
data.isnull().sum()
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# median_house_value      0
# ocean_proximity         0
# dtype: int64

# %% [raw]
# as we can see 207 values are null

# %%
data.dropna(inplace=True)

# %%
data.isnull().sum()
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# ocean_proximity       0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20433 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20433 non-null  float64
#  1   latitude            20433 non-null  float64
#  2   housing_median_age  20433 non-null  float64
#  3   total_rooms         20433 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20433 non-null  float64
#  6   households          20433 non-null  float64
#  7   median_income       20433 non-null  float64
#  8   median_house_value  20433 non-null  float64
#  9   ocean_proximity     20433 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.7+ MB

# %% [markdown]
# so we drop all the null values in total_bedroms and that caused to drop all the row corresponding to it with means 207 rows we finally have only 20433 row

# %%
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
from sklearn.model_selection import train_test_split
X=data.drop(['median_house_value'],axis=1)
Y=data['median_house_value']
x_train,x_test,y_train,y_test=train_test_split(X,Y,test_size=0.2)

# %%
data_train=x_train.join(y_train)
data_test=x_test.join(y_test)

# %%
data_test
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 189      -122.24     37.79                47.0       1372.0           395.0
# 7696     -118.12     33.95                35.0       1604.0           280.0
# 1553     -121.98     37.80                17.0       3354.0           422.0
# 16749    -122.47     37.70                45.0       3290.0           693.0
# 3637     -118.44     34.23                36.0       1730.0           387.0
# ...          ...       ...                 ...          ...             ...
# 8238     -118.18     33.77                39.0       1645.0           547.0
# 6565     -118.14     34.19                45.0       3595.0           619.0
# 33       -122.27     37.83                49.0       1655.0           366.0
# 8803     -118.40     33.78                26.0       5005.0           776.0
# 615      -122.16     37.73                52.0       2260.0           416.0
#
# ...

# %%
data_train
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 1883     -119.99     38.94                22.0       3119.0           640.0
# 5859     -118.33     34.18                45.0       1552.0           315.0
# 59       -122.29     37.82                 2.0        158.0            43.0
# 13787    -117.29     35.54                35.0       7922.0          1636.0
# 11260    -117.99     33.80                25.0       3179.0           639.0
# ...          ...       ...                 ...          ...             ...
# 6762     -118.13     34.09                21.0       3862.0          1186.0
# 15316    -117.36     33.20                19.0       1926.0           557.0
# 19093    -122.61     38.25                18.0       2915.0           418.0
# 13219    -117.69     34.00                28.0        707.0           154.0
# 14406    -117.25     32.77                32.0       2021.0           524.0
#
# ...

# %%
data_train.hist(figsize=(15,8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
plt.figure(figsize=(15,8))
sns.heatmap(data_train.select_dtypes(include=['number']).corr(),annot=True,cmap="YlGnBu")
# Out:
# <Axes: >

# %% [markdown]
# as we can see in the hist the variable is not normally distributed so
# The np.log function is used to apply the natural logarithm transformation to the values. This transformation often helps in making the distribution of the data more symmetric and closer to a normal distribution.

# %%
data_train['total_rooms']=np.log(data_train['total_rooms'])

# %%
data_train.hist(figsize=(15,8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %% [markdown]
# now total_rooms look closer to the normal distribution

# %% [markdown]
# now we need to deal with ocean_proximity which non numerical variable

# %%
data_train.ocean_proximity.value_counts()
data_test.ocean_proximity.value_counts()
# Out:
# ocean_proximity
# <1H OCEAN     1800
# INLAND        1320
# NEAR OCEAN     522
# NEAR BAY       444
# ISLAND           1
# Name: count, dtype: int64

# %%
pd.get_dummies(data_train.ocean_proximity)
# Out:
#        <1H OCEAN  INLAND  ISLAND  NEAR BAY  NEAR OCEAN
# 19709      False    True   False     False       False
# 7560        True   False   False     False       False
# 7408        True   False   False     False       False
# 18384       True   False   False     False       False
# 1098       False    True   False     False       False
# ...          ...     ...     ...       ...         ...
# 3477        True   False   False     False       False
# 17632       True   False   False     False       False
# 15391       True   False   False     False       False
# 2566       False   False   False     False        True
# 203        False   False   False      True       False
#
# [16346 rows x 5 columns]

# %%
data_train=data_train.join(pd.get_dummies(data_train.ocean_proximity)).drop(['ocean_proximity'],axis=1)

# %%
data_train
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 19709    -121.63     39.18                13.0       1907.0           347.0
# 7560     -118.20     33.91                36.0       2283.0           499.0
# 7408     -118.22     33.96                35.0       1437.0           474.0
# 18384    -121.84     37.21                15.0       5468.0           676.0
# 1098     -121.74     39.59                24.0       1535.0           279.0
# ...          ...       ...                 ...          ...             ...
# 3477     -118.51     34.30                24.0       6145.0           868.0
# 17632    -121.92     37.27                33.0       3280.0           569.0
# 15391    -116.98     33.26                12.0       5898.0          1002.0
# 2566     -124.16     40.78                46.0       1975.0           346.0
# 203      -122.23     37.78                52.0        986.0           258.0
#
# ...

# %%
plt.figure(figsize=(15,8))
sns.heatmap(data_train.corr(),annot=True,cmap="YlGnBu")
# Out:
# <Axes: >

# %%
from sklearn.linear_model import LinearRegression
X_train,Y_train=data_train.drop(['median_house_value'],axis=1),data_train['median_house_value']
rg=LinearRegression()
rg.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
pd.get_dummies(data_test.ocean_proximity)
# Out:
#        <1H OCEAN  INLAND  ISLAND  NEAR BAY  NEAR OCEAN
# 189        False   False   False      True       False
# 7696        True   False   False     False       False
# 1553        True   False   False     False       False
# 16749      False   False   False     False        True
# 3637        True   False   False     False       False
# ...          ...     ...     ...       ...         ...
# 8238       False   False   False     False        True
# 6565       False    True   False     False       False
# 33         False   False   False      True       False
# 8803       False   False   False     False        True
# 615        False   False   False      True       False
#
# [4087 rows x 5 columns]

# %%
data_test=data_test.join(pd.get_dummies(data_test.ocean_proximity)).drop(['ocean_proximity'],axis=1)

# %%
data_test
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 189      -122.24     37.79                47.0       1372.0           395.0
# 7696     -118.12     33.95                35.0       1604.0           280.0
# 1553     -121.98     37.80                17.0       3354.0           422.0
# 16749    -122.47     37.70                45.0       3290.0           693.0
# 3637     -118.44     34.23                36.0       1730.0           387.0
# ...          ...       ...                 ...          ...             ...
# 8238     -118.18     33.77                39.0       1645.0           547.0
# 6565     -118.14     34.19                45.0       3595.0           619.0
# 33       -122.27     37.83                49.0       1655.0           366.0
# 8803     -118.40     33.78                26.0       5005.0           776.0
# 615      -122.16     37.73                52.0       2260.0           416.0
#
# ...

# %%
data_test
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 189      -122.24     37.79                47.0       1372.0           395.0
# 7696     -118.12     33.95                35.0       1604.0           280.0
# 1553     -121.98     37.80                17.0       3354.0           422.0
# 16749    -122.47     37.70                45.0       3290.0           693.0
# 3637     -118.44     34.23                36.0       1730.0           387.0
# ...          ...       ...                 ...          ...             ...
# 8238     -118.18     33.77                39.0       1645.0           547.0
# 6565     -118.14     34.19                45.0       3595.0           619.0
# 33       -122.27     37.83                49.0       1655.0           366.0
# 8803     -118.40     33.78                26.0       5005.0           776.0
# 615      -122.16     37.73                52.0       2260.0           416.0
#
# ...

# %%
X_test,Y_test=data_test.drop(['median_house_value'],axis=1),data_test['median_house_value']

# %%
X_test
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 189      -122.24     37.79                47.0       1372.0           395.0
# 7696     -118.12     33.95                35.0       1604.0           280.0
# 1553     -121.98     37.80                17.0       3354.0           422.0
# 16749    -122.47     37.70                45.0       3290.0           693.0
# 3637     -118.44     34.23                36.0       1730.0           387.0
# ...          ...       ...                 ...          ...             ...
# 8238     -118.18     33.77                39.0       1645.0           547.0
# 6565     -118.14     34.19                45.0       3595.0           619.0
# 33       -122.27     37.83                49.0       1655.0           366.0
# 8803     -118.40     33.78                26.0       5005.0           776.0
# 615      -122.16     37.73                52.0       2260.0           416.0
#
# ...

# %%
Y_test
# Out:
# 189       95500.0
# 7696     291000.0
# 1553     345800.0
# 16749    238600.0
# 3637     183100.0
#            ...
# 8238     155000.0
# 6565     201000.0
# 33       104900.0
# 8803     500001.0
# 615      198200.0
# Name: median_house_value, Length: 4087, dtype: float64

# %%
rg.score(X_test,Y_test)#R**2 score to
# Out:
# 0.6548056099098911
